# %%
# %matplotlib inline
from src.plot_feature import *

# visualize model features from random samples to display ROI (regions of interest) the moodel focuses on
plot = plot_features_from_random_example
print(plot.__doc__)
plot(example_num=params['visual']['feature']['example_num'],
     model_tool=params['model']['tool'], 
     model_name=params['model']['name'], 
     save_path=os.path.join(params['evaluate']['dir_prefix'], params['model']['name']),
     img_size_inch=params['visual']['feature']['img_size_inch'],
     architect=params['model']['architect'],
)
# Out:
#     models currenctly supported:
#         - pytorch
#             - ResNet-50
#             - ResNet-18
#             - VGG-19
#         - tensorflow
#             - N/A
